# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.105-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.105-py3-none-any.whl (994 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 24.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 76.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.105 ultralytics-thop-2.0.14

# %%
# !unzip /content/drive/MyDrive/Capstone/Yolo+deepsort/deep_sort.zip
# Out:
# Archive:  /content/drive/MyDrive/Capstone/Yolo+deepsort/deep_sort.zip
#    creating: deep_sort/
#   inflating: deep_sort/.gitignore
#    creating: deep_sort/application_util/
#   inflating: deep_sort/application_util/image_viewer.py
#   inflating: deep_sort/application_util/preprocessing.py
#   inflating: deep_sort/application_util/visualization.py
#  extracting: deep_sort/application_util/__init__.py
#    creating: deep_sort/deep_sort/
#   inflating: deep_sort/deep_sort/detection.py
#   inflating: deep_sort/deep_sort/iou_matching.py
#   inflating: deep_sort/deep_sort/kalman_filter.py
#   inflating: deep_sort/deep_sort/linear_assignment.py
#   inflating: deep_sort/deep_sort/nn_matching.py
#   inflating: deep_sort/deep_sort/track.py
#   inflating: deep_sort/deep_sort/tracker.py
#  extracting: deep_sort/deep_sort/__init__.py
#    creating: deep_sort/deep_sort/__pycache__/
#   inflating: deep_sort/deep_sort/__pycache__/detection.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/iou_matching.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/kalman_filter.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/linear_assignment.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/nn_matching.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/track.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/tracker.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/__init__.cpython-312.pyc
#   inflating: deep_sort/deep_sort_app.py
#   inflating: deep_sort/evaluate_motchallenge.py
#   inflating: deep_sort/generate_videos.py
#   inflating: deep_sort/LICENSE
#   inflating: deep_sort/README.md
#   inflating: deep_sort/show_results.py
#    creating: deep_sort/tools/
#   inflating: deep_sort/tools/freeze_model.py
#   inflating: deep_sort/tools/generate_detections.py
#    creating: deep_sort/tools/__pycache__/
#   inflating: deep_sort/tools/__pycache__/generate_detections.cpython-312.pyc

# %%
###객체추적_v3_deepsort2

import cv2
import numpy as np
import pandas as pd
from ultralytics import YOLO

# DeepSORT 관련 모듈
from deep_sort.deep_sort.tracker import Tracker as DeepSortTracker
from deep_sort.tools import generate_detections as gdet
from deep_sort.deep_sort import nn_matching
from deep_sort.deep_sort.detection import Detection
from collections import Counter

print("Imports done.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Imports done.

# %%
mars_small128 = "/content/drive/MyDrive/Capstone/Yolo+deepsort/mars-small128.pb"

# %%
### Deepsort 연결을 위한 class 2개 생성성
class Track:
    def __init__(self, track_id, bbox):
        self.track_id = track_id
        self.bbox = bbox


class DeepSortWrapper:
    def __init__(self, model_filename= mars_small128, max_cosine_distance=0.4, nn_budget=None):
        metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
        self.tracker = DeepSortTracker(metric)
        self.encoder = gdet.create_box_encoder(model_filename, batch_size=1)
        self.tracks = []

    def update(self, frame, detections):

        # Step 1: If no detections, run a predict-update cycle with an empty list.
        if len(detections) == 0:
            self.tracker.predict()
            self.tracker.update([])
            self._update_tracks()
            return

        # Step 2: Convert [x1, y1, x2, y2] to [x, y, w, h] for Deep SORT
        bboxes = np.array([d[:4] for d in detections])
        scores = [d[4] for d in detections]
        bboxes[:, 2:] = bboxes[:, 2:] - bboxes[:, :2]

        # Step 3: Generate appearance features for each bounding box
        features = self.encoder(frame, bboxes)

        # Step 4: Wrap everything in Deep SORTs Detection objects
        dets = []
        for bbox_id, bbox in enumerate(bboxes):
            dets.append(Detection(bbox, scores[bbox_id], features[bbox_id]))

        # Step 5: Predict and update the tracker
        self.tracker.predict()
        self.tracker.update(dets)
        self._update_tracks()

    def _update_tracks(self):
        active_tracks = []
        for track in self.tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue
            bbox = track.to_tlbr()  # returns [x1, y1, x2, y2]
            track_id = track.track_id
            active_tracks.append(Track(track_id, bbox))

        self.tracks = active_tracks

# %%
### tensorflow-gpu 연결에는 문제가 없으나 deepsort의 gpu이용에 문제.
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')  # DeepSORT가 GPU를 사용하지 않도록 설정

# %%
# import math

# # YOLO 모델 로드
# model_weight_path = "/content/drive/MyDrive/Capstone/best_motorcycle_detector_NIGHT8.pt"
# model = YOLO(model_weight_path)
# model.to('cuda')  # GPU 사용

# # DeepSORT 초기화
# ### DeepSORTWrapper와 Mars
# tracker = DeepSortWrapper(model_filename='/content/mars-small128.pb', max_cosine_distance=0.2, nn_budget=None)
# print("YOLO model and Deep SORT wrapper initialized.")

# # 전역 변수 정의
# log_data = []
# interval_data = []
# detected_classes = []
# object_data = {}
# object_directions = {}
# pair_code_map = {}  # Pair Code 매핑
# pair_code_counter = 1  # Pair Code 생성용
# object_class_counts = {}

# frame_counter = 0
# pixel_to_meter_ratio = None

# # 영역 정의 (YOLO 형식)
# right_turn_zone_yolo = (0.399740, 0.538426, 0.067187, 0.152778)
# straight_zone_yolo = (0.810417, 0.805093, 0.141667, 0.171296)
# interval_zone_yolo = (0.467187, 0.759722, 0.837500, 0.515741)
# finish_zone_yolo = (0.044271, 0.858333, 0.081250, 0.211111)
# actual_interval_width = 47.0  # 실제 평가 거리 (미터)

# # 고유 ID 생성 및 유지
# # def get_unique_id(track_id):
# #     if track_id not in unique_ids:
# #         unique_ids[track_id] = str(uuid.uuid4())[:8]
# #     return unique_ids[track_id]

# # 픽셀-to-미터 변환 비율 계산
# def calculate_pixel_to_meter_ratio(frame_width):
#     interval_width_pixels = interval_zone_yolo[2] * frame_width
#     if interval_width_pixels < 1:
#         print("Error: interval_width_pixels is 0, check interval_zone_yolo values.")
#         return 1.0  # 혹은 기본값 설정
#     pixel_to_meter_ratio = actual_interval_width / interval_width_pixels

#     if pixel_to_meter_ratio < 0.01:
#         print(f"[DEBUG] pixel_to_meter_ratio 값이 너무 작아 기본값(0.1)로 설정합니다.")
#         pixel_to_meter_ratio = 0.1

#     print(f"[DEBUG] Pixel-to-Meter Ratio : {pixel_to_meter_ratio}")
#     return pixel_to_meter_ratio

# # YOLO 형식의 좌표를 픽셀 좌표로 변환
# def yolo_to_pixel(label, img_width, img_height, max_size=2000):
#     # YOLO format: (x_center, y_center, width, height)
#     x_center, y_center, width, height = label

#     # 상대 좌표를 픽셀 좌표로 변환
#     x1 = (x_center - width / 2) * img_width
#     x2 = (x_center + width / 2) * img_width
#     y1 = (y_center - height / 2) * img_height
#     y2 = (y_center + height / 2) * img_height

#     # 바운딩 박스 크기가 너무 커지지 않도록 제한
#     width_pixels = max(0, min(max_size, x2 - x1))
#     height_pixels = max(0, min(max_size, y2 - y1))

#     # 좌표 범위 보정
#     x1 = max(0, min(x1, img_width - width_pixels))
#     x2 = x1 + width_pixels
#     y1 = max(0, min(y1, img_height - height_pixels))
#     y2 = y1 + height_pixels

#     # 디버깅 출력
#     print(f"YOLO Output (x_center, y_center, width, height): {label}")
#     print(f"Converted Pixel BBox: ({x1}, {y1}, {x2}, {y2})")

#     return (int(x1), int(y1), int(x2), int(y2))

# # BBox가 특정 Zone과 교차 또는 포함되는지 확인
# def is_bbox_in_zone(bbox, zone):
#     (x1, y1, x2, y2) = bbox
#     (z_x1, z_y1, z_x2, z_y2) = zone
#     return not (x2 < z_x1 or x1 > z_x2 or y2 < z_y1 or y1 > z_y2)

# # BBox를 기준으로 차량의 방향(우회전/직진)을 분류
# def classify_direction(bbox, frame_width, frame_height):
#     right_turn_zone = yolo_to_pixel(right_turn_zone_yolo, frame_width, frame_height)
#     straight_zone = yolo_to_pixel(straight_zone_yolo, frame_width, frame_height)

#     if is_bbox_in_zone(bbox, right_turn_zone):
#         return "우회전"
#     elif is_bbox_in_zone(bbox, straight_zone):
#         return "직진"
#     return "미정"

# def calculate_angle(dx, dy):
#     if dx == 0:
#         return 90 if dy > 0 else -90  # 위쪽 이동(90도), 아래쪽 이동(-90도)
#     return math.degrees(math.atan2(dy, dx))
# # import math

# # def calculate_angle(dx, dy):
# #     """
# #     이동 벡터 (dx, dy)를 이용해 각도를 계산하는 함수.
# #     :param dx: X축 이동 거리
# #     :param dy: Y축 이동 거리
# #     :return: 이동 각도 (degree)
# #     """
# #     angle = math.degrees(math.atan2(dy, dx))  # atan2는 (-180 ~ 180) 범위 반환
# #     return angle



# def determine_movement_direction(track_id, current_position):
#     """
#     객체의 이동 벡터를 계산하고, 실제 이동 방향을 분석하여 반환하는 함수.
#     - 수평(왼쪽) 이동 → "직진"
#     - 아래쪽 이동 → "우회전"
#     - 그 외 → "미정"

#     :param track_id: 객체의 고유 추적 ID
#     :param current_position: 현재 프레임에서의 객체 중심점 (x, y)
#     :return: 이동 방향 ("직진", "우회전", "미정")
#     """
#     if track_id in object_data:
#         prev_position = object_data[track_id]["position"]

#         # 이동 벡터 계산
#         dx = current_position[0] - prev_position[0]  # X축 이동 거리
#         dy = current_position[1] - prev_position[1]  # Y축 이동 거리

#         # 이동 방향 각도 계산
#        # angle = calculate_angle(dx, dy)

#         # ✅ 이동 방향 판별
#         if dx < 0:  # 왼쪽 방향 (거의 수평 이동)
#             direction = "직진"
#         elif dy > 0:  # 아래쪽 이동 → 우회전 가능
#             direction = "우회전"
#         else:
#             direction = "미정"  # 방향을 알 수 없는 경우

#         # 객체 데이터 업데이트 (현재 위치를 새로운 기준점으로 저장)
#         object_data[track_id] = {"position": current_position, "direction": direction}

#         return direction
#     else:
#         # 처음 감지된 객체 → "미정" 상태로 설정
#         object_data[track_id] = {"position": current_position, "direction": "미정"}
#         return "미정"

# # 이동 거리, 속도, 가속도 계산
# import numpy as np


# def calculate_motion(object_id, current_position, fps, pixel_to_meter_ratio):
#     if object_id in object_data:
#         prev_data = object_data[object_id]
#         prev_pos = prev_data.get("position",current_position)
#         prev_speed = prev_data.get("speed",0.0)

#         # 이전 위치가 현재 위치와 동일하면 거리 계산 제외
#         #if np.array_equal(prev_pos, current_position):
#         #    print(f"[DEBUG] Object {object_id} did not move.")
#         #    return 0.0, prev_speed, 0.0


#         # 거리 및 속도 계산
#         distance_pixels = np.linalg.norm(np.array(current_position) - np.array(prev_pos))
#         distance_meters = distance_pixels * pixel_to_meter_ratio
#         speed = distance_meters * fps
#         acceleration = (speed - prev_speed) * fps

#         # 가속도가 비정상적으로 클 경우 제한
#         if acceleration > 100:
#             print(f"[DEBUG] Object {object_id} - Acceleration 너무 큼: {acceleration:.2f}m/s² → 100으로 제한")
#             acceleration = 100
#                 # 이동이 감지되지 않으면 로그를 남기지 않음

#         if distance_meters < 0.01:
#             return 0.0, prev_speed, 0.0  # 🔹 작은 이동은 무시

#         # 디버깅 정보 출력
#         print(f"[DEBUG] Object {object_id} - Distance: {distance_meters:.2f}m, Speed: {speed:.2f}m/s, Accel: {acceleration:.2f}m/s²")

#         # 객체 정보 업데이트
#         object_data[object_id] = {"position": current_position, "speed": speed}
#         return distance_meters, speed, acceleration

#     else:
#         # 객체가 처음 등장했을 때 초기화
#         object_data[object_id] = {"position": current_position, "speed": 0.0}
#         print(f"[DEBUG] Object {object_id} initialized.")
#         return 0.0, 0.0, 0.0


# # 객체 클래스 변경 함수
# def update_object_class(track_id, new_class):
#     track_id = str(track_id)

#     if track_id not in object_class_counts:
#         object_class_counts[track_id] = Counter()

#     # 새로운 클래스를 카운트
#     object_class_counts[track_id][new_class] += 1

#     # 가장 빈도가 높은 클래스를 가져옴
#     most_common_class = object_class_counts[track_id].most_common(1)[0][0]
#     class_label = "car" if most_common_class == 2 else "motorcycle"

#     # 객체의 클래스가 결정되면 모든 프레임에서 해당 클래스를 업데이트
#     for obj in log_data:
#         if obj["Object ID"] == track_id:
#             obj["Class"] = class_label

#     # interval_data에도 반영 (추가된 부분)
#     for interval in interval_data:
#         if interval["Object 1 ID"] == track_id:
#             interval["Object 1 Class"] = class_label
#         if interval["Object 2 ID"] == track_id:
#             interval["Object 2 Class"] = class_label
#     return most_common_class

# # Interval 데이터 생성
# def update_interval_data(frame_num, log_data, pixel_to_meter_ratio):
#     global interval_data, pair_code_map, pair_code_counter

#     right_turn_vehicles = [obj for obj in log_data if obj["Direction"] == "우회전"]
#     straight_vehicles = [obj for obj in log_data if obj["Direction"] == "직진" or obj["Direction"]=="미정"]

#     for obj1 in right_turn_vehicles:
#         for obj2 in straight_vehicles:
#             if not obj1.get("Object ID") or not obj2.get("Object ID"):
#                 continue

#             # 중심점 거리 계산
#             center1 = ((obj1["BBox"][0] + obj1["BBox"][2]) / 2, (obj1["BBox"][1] + obj1["BBox"][3]) / 2)
#             center2 = ((obj2["BBox"][0] + obj2["BBox"][2]) / 2, (obj2["BBox"][1] + obj2["BBox"][3]) / 2)
#             lag_spacing_pixels = np.linalg.norm(np.array(center1) - np.array(center2))
#             lag_spacing_meters = lag_spacing_pixels * pixel_to_meter_ratio

#             # 고유 Pair Code 생성 및 관리
#             pair_key = (obj1["Object ID"], obj2["Object ID"])
#             if pair_key not in pair_code_map:
#                 pair_code_map[pair_key] = pair_code_counter
#                 pair_code_counter += 1

#             interval_data.append({
#                 "Frame": frame_num,
#                 "Object 1 ID": obj1["Object ID"],
#                 "Object 2 ID": obj2["Object ID"],
#                 "Pair Code": pair_code_map[pair_key],
#                 "Lag Spacing (m)": lag_spacing_meters,
#                 "Object 1 Speed (m/s)": obj1["Speed (m/s)"],
#                 "Object 2 Speed (m/s)": obj2["Speed (m/s)"],
#                 "Object 1 Class": obj1["Class"],
#                 "Object 2 Class": obj2["Class"]
#             })

# # YOLO 결과를 DeepSORT 입력으로 변환
# def yolo_to_deepsort(yolo_results, target_classes):
#     detections = []
#     classes = []
#     for det in yolo_results[0].boxes:
#         x1, y1, x2, y2 = map(float, det.xyxy[0].cpu().numpy())
#         confidence = float(det.conf.cpu().numpy().item())
#         class_id = int(det.cls.cpu().numpy())
#         if class_id in target_classes:
#             detections.append([(x1, y1, x2, y2), confidence])
#             classes.append(class_id)

#             # 디버깅 로그 추가: YOLO에서 DeepSORT로 전달되는 바운딩 박스 및 신뢰도 출력
#             print(f"YOLO to DeepSORT - BBox: ({x1}, {y1}, {x2}, {y2}), Confidence: {confidence}, Class ID: {class_id}")

#     return detections, classes

# # 객체 클래스별 색상 반환 함수
# def get_class_color(class_id):
#     if class_id == 2:  # car
#         return (0, 255, 0)  # 초록 (BGR)
#     else:
#         return (255, 0, 0)  # 파랑 (BGR)

# # 수정된 메인 루프

# if __name__ == "__main__":
#     target_classes = [2, 3]  # car(2), motorcycle(3)

#     video_path = "/content/drive/MyDrive/Capstone/11.15 1800-2000/11.15 1800-1830 - 필터링.mp4"
#     cap = cv2.VideoCapture(video_path)
#     if not cap.isOpened():
#       print(f"Error: Unable to open video file {video_path}")

#     fps = int(cap.get(cv2.CAP_PROP_FPS))

#     if fps <= 0 or fps > 60:
#       print(f"[DEBUG] FPS 값이 비정상적({fps}), 기본값(30)으로 설정합니다.")
#       fps = 30

#     print(f"[DEBUG] FPS: {fps}")

#     frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#     frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#     if frame_width == 0 or frame_height == 0:
#       print("Error: Invalid video frame dimensions")

#     pixel_to_meter_ratio = calculate_pixel_to_meter_ratio(frame_width)

#     output_directory = "/content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Log video"
#     import os
#     output_video_path = os.path.join(output_directory, '11.15 1800-1830_processed_videoA.avi')
#     video_writer = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*'MJPG'), fps, (frame_width, frame_height))

#     while cap.isOpened():
#         ret, frame = cap.read()
#         if not ret:
#             break

#         frame_counter += 1

#         # YOLO 객체 검출
#         results = model(frame, conf=0.3)

#         valid_classes = {2:"car",3:"motorcycle", 5:"bus", 7:"truck"}
#         class_counts = {"car":0,"motorcycle":0, "bus":0,"truck:0"}

#         # YOLO 결과를 DeepSORT로 변환
#         detected_classes.clear()
#         all_detections = []

#         for r in results:
#             for box in r.boxes.data.tolist():
#               x1, y1, x2, y2, score, class_id = box
#               if score >= 0.5:
#                 class_name = valid_classes[int(class_id)]
#                 class_counts[class_name] = class_counts.get(class_name, 0) + 1
#                 all_detections.append([int(x1),int(y1),int(x2),int(y2),float(score)])
#                 detected_classes.append(int(class_id))
#         # Ensure detected_classes and tracker.tracks have the same length
#         if len(all_detections) != len(detected_classes):
#             print(f"Warning: Mismatch between detections ({len(all_detections)}) and detected classes ({len(detected_classes)})")

#         # DeepSORTWrapper로 추적
#         tracker.update(frame, all_detections)
#         if not detected_classes:
#             print("Warning: No detected classes were found, skipping classification.")

#         current_log_data = []
#         for track, detected_class_id in zip(tracker.tracks,detected_classes):
#             track_id = track.track_id
#             x1, y1, x2, y2 = track.bbox

#             # DeepSORT에서 제공하는 track_id를 사용하여 class_id를 가져옴
#             #class_id = update_object_class(track_id, 2)  # 기본값 2(car)로 설정

#             # 디버깅: 클래스 ID와 색상 확인
#             print(f"Track ID: {track_id}, Updated Class ID: {class_id}")

#             updated_class_id = update_object_class(track_id, detected_class_id)

#             color = get_class_color(updated_class_id)  # 🔹 color 변수 정의 추가

#             cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)

#             if f"ID {track_id}" not in log_data:
#                 label = "car" if updated_class_id == 2 else "motorcycle"
#                 direction = object_directions.get(track_id, "미정")

#                 cv2.putText(frame, f"{label} ID {track_id} {direction}",
#                             (int(x1), int(y1) - 10),
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)


#             # 바운딩 박스 x좌표가 음수인 경우, 추적 중단
#             if x1 < 0 or y1 < 0 or x2 < 0 or y2 < 0:
#                 continue

#             current_position = ((x1 + x2) // 2, (y1 + y2) // 2)
#             print(f"[DEBUG] Frame {frame_counter} - Object {track_id} Previous Position: {object_data.get(track_id, {}).get('position', 'N/A')} -> Current Position: {current_position}")

#             #unique_id = get_unique_id(track_id)



#             # 이동 거리, 속도, 가속도 계산
#             distance, speed, acceleration = calculate_motion(track_id, current_position, fps, pixel_to_meter_ratio)

#             # 이동 벡터를 기반으로 실제 이동 방향 결정
#             direction = determine_movement_direction(track_id, current_position)

#             bbox = (int(x1), int(y1), int(x2), int(y2))

#             # 방향 분류
#             direction = object_directions.get(track_id, "미정")
#             if direction == "미정":
#                 direction = classify_direction(bbox, frame_width, frame_height)
#                 object_directions[track_id] = direction

#             # 로그 데이터 기록
#             bbox = (int(x1), int(y1), int(x2), int(y2))

#             #if not any(obj["Object ID"] == track_id for obj in log_data):
#             if is_bbox_in_zone(bbox, yolo_to_pixel(interval_zone_yolo, frame_width, frame_height)):
#                 direction = classify_direction(bbox, frame_width, frame_height)

#                 obj_data = {
#                     "Frame": frame_counter,
#                     "Object ID": track_id,
#                     "Class": "car" if updated_class_id == 2 else "motorcycle",
#                     "Distance (m)": distance,
#                     "Speed (m/s)": speed,
#                     "Acceleration (m/s^2)": acceleration,
#                     "Direction": direction,
#                     "BBox": (x1, y1, x2, y2)
#                 }
#             log_data.append(obj_data)
#             current_log_data.append(obj_data)

#             # 화면 표시
#             label = ""
#             if updated_class_id == 2:
#                 label = "car"
#             elif updated_class_id == 3:
#                 label = "motorcycle"

#             color = get_class_color(updated_class_id)
# #            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
#             cv2.putText(frame, f"{label} ID {track_id} {direction}", (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,color, 2)

#         # Interval 데이터 업데이트
#         update_interval_data(frame_counter, current_log_data, pixel_to_meter_ratio)

#         if not video_writer.isOpened():
#             print("Error: VideoWriter failed to open.")

#         if frame is None:
#             print(f"Error: Empty frame at {frame_counter}")




#         # 비디오 저장
#         video_writer.write(frame)
#         # 객체 ID 및 바운딩 박스 정보 로그 출력
#         #print(f"Object ID: {unique_id}, BBox: ({x1}, {y1}, {x2}, {y2}), Direction: {direction}")


#     # 데이터 저장
#     log_data_path = "/content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Log data/1800-1830_logA.csv"
#     interval_data_path = "/content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Interval data/1800-1830_intervalA.csv"
#     pd.DataFrame(log_data).to_csv(log_data_path, index=False)
#     pd.DataFrame(interval_data).to_csv(interval_data_path, index=False)


#     print(f"Log data saved to: {log_data_path}")
#     print(f"Interval data saved to: {interval_data_path}")

#     cap.release()
#     video_writer.release()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 2.0
# [DEBUG] Frame 2282 - Object 189 Previous Position: (1222.0, 731.0) -> Current Position: (1218.0, 730.0)
# [DEBUG] Object 189 - Acceleration 너무 큼: 108.46m/s² → 100으로 제한
# [DEBUG] Object 189 - Distance: 0.12m, Speed: 3.62m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 193, Updated Class ID: 2.0
# [DEBUG] Frame 2282 - Object 193 Previous Position: (610.0, 902.0) -> Current Position: (593.0, 902.0)
# [DEBUG] Object 193 - Acceleration 너무 큼: 447.20m/s² → 100으로 제한
# [DEBUG] Object 193 - Distance: 0.50m, Speed: 14.91m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2282 - Object 199 Previous Position: (1836.0, 826.0) -> Current Position: (1832.0, 825.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 108.46m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.12m, Speed: 3.62m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# Track ID: 200, Updated Class ID: 2.0
# [DEBUG] Frame 2282 - Object 200 Previous Position: (879.0, 515.0) -> Current Position: (879.0, 515.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 7 cars, 1 motorcycle, 16.6ms
# Speed: 3.6ms preprocess, 16.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2283 - Object 176 Previous Position: (484.0, 992.0) -> Current Position: (484.0, 991.0)
# [DEBUG] Object 176 - Distance: 0.03m, Speed: 0.88m/s, Accel: 26.31m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2283 - Object 184 Previous Position: (623.0, 738.0) -> Current Position: (620.0, 738.0)
# [DEBUG] Object 184 - Distance: 0.09m, Speed: 2.63m/s, Accel: 78.92m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 2.0
# [DEBUG] Frame 2283 - Object 189 Previous Position: (1218.0, 730.0) -> Current Position: (1214.0, 728.0)
# [DEBUG] Object 189 - Acceleration 너무 큼: 117.64m/s² → 100으로 제한
# [DEBUG] Object 189 - Distance: 0.13m, Speed: 3.92m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 193, Updated Class ID: 2.0
# [DEBUG] Frame 2283 - Object 193 Previous Position: (593.0, 902.0) -> Current Position: (579.0, 903.0)
# [DEBUG] Object 193 - Acceleration 너무 큼: 369.22m/s² → 100으로 제한
# [DEBUG] Object 193 - Distance: 0.41m, Speed: 12.31m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2283 - Object 199 Previous Position: (1832.0, 825.0) -> Current Position: (1828.0, 826.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 108.46m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.12m, Speed: 3.62m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# Track ID: 200, Updated Class ID: 2.0
# [DEBUG] Frame 2283 - Object 200 Previous Position: (879.0, 515.0) -> Current Position: (879.0, 515.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 6 cars, 1 motorcycle, 12.9ms
# Speed: 6.1ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2284 - Object 176 Previous Position: (484.0, 991.0) -> Current Position: (484.0, 991.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2284 - Object 184 Previous Position: (620.0, 738.0) -> Current Position: (618.0, 740.0)
# [DEBUG] Object 184 - Distance: 0.08m, Speed: 2.48m/s, Accel: 74.40m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 2.0
# [DEBUG] Frame 2284 - Object 189 Previous Position: (1214.0, 728.0) -> Current Position: (1210.0, 727.0)
# [DEBUG] Object 189 - Acceleration 너무 큼: 108.46m/s² → 100으로 제한
# [DEBUG] Object 189 - Distance: 0.12m, Speed: 3.62m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 193, Updated Class ID: 2.0
# [DEBUG] Frame 2284 - Object 193 Previous Position: (579.0, 903.0) -> Current Position: (566.0, 902.0)
# [DEBUG] Object 193 - Acceleration 너무 큼: 342.99m/s² → 100으로 제한
# [DEBUG] Object 193 - Distance: 0.38m, Speed: 11.43m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2284 - Object 199 Previous Position: (1828.0, 826.0) -> Current Position: (1824.0, 826.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 105.22m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.12m, Speed: 3.51m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
#
# 0: 384x640 6 cars, 1 motorcycle, 13.4ms
# Speed: 3.7ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2285 - Object 184 Previous Position: (618.0, 740.0) -> Current Position: (615.0, 742.0)
# [DEBUG] Object 184 - Distance: 0.11m, Speed: 3.16m/s, Accel: 94.85m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 2.0
# [DEBUG] Frame 2285 - Object 189 Previous Position: (1210.0, 727.0) -> Current Position: (1206.0, 726.0)
# [DEBUG] Object 189 - Acceleration 너무 큼: 108.46m/s² → 100으로 제한
# [DEBUG] Object 189 - Distance: 0.12m, Speed: 3.62m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 193, Updated Class ID: 2.0
# [DEBUG] Frame 2285 - Object 193 Previous Position: (566.0, 902.0) -> Current Position: (551.0, 903.0)
# [DEBUG] Object 193 - Acceleration 너무 큼: 395.47m/s² → 100으로 제한
# [DEBUG] Object 193 - Distance: 0.44m, Speed: 13.18m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2285 - Object 199 Previous Position: (1824.0, 826.0) -> Current Position: (1819.0, 826.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 131.53m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.15m, Speed: 4.38m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# Track ID: 200, Updated Class ID: 2.0
# [DEBUG] Frame 2285 - Object 200 Previous Position: (879.0, 515.0) -> Current Position: (879.0, 515.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 6 cars, 1 motorcycle, 13.7ms
# Speed: 12.8ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 184, Updated Class ID: 3.0
# [DEBUG] Frame 2286 - Object 184 Previous Position: (615.0, 742.0) -> Current Position: (613.0, 743.0)
# [DEBUG] Object 184 - Distance: 0.07m, Speed: 1.96m/s, Accel: 58.82m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 3.0
# [DEBUG] Frame 2286 - Object 189 Previous Position: (1206.0, 726.0) -> Current Position: (1202.0, 723.0)
# [DEBUG] Object 189 - Acceleration 너무 큼: 131.53m/s² → 100으로 제한
# [DEBUG] Object 189 - Distance: 0.15m, Speed: 4.38m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 193, Updated Class ID: 3.0
# [DEBUG] Frame 2286 - Object 193 Previous Position: (551.0, 903.0) -> Current Position: (538.0, 904.0)
# [DEBUG] Object 193 - Acceleration 너무 큼: 342.99m/s² → 100으로 제한
# [DEBUG] Object 193 - Distance: 0.38m, Speed: 11.43m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 3.0
# [DEBUG] Frame 2286 - Object 199 Previous Position: (1819.0, 826.0) -> Current Position: (1813.0, 826.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 157.84m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.18m, Speed: 5.26m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
#
# 0: 384x640 7 cars, 1 motorcycle, 11.3ms
# Speed: 11.4ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2287 - Object 184 Previous Position: (613.0, 743.0) -> Current Position: (610.0, 743.0)
# [DEBUG] Object 184 - Distance: 0.09m, Speed: 2.63m/s, Accel: 78.92m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 2.0
# [DEBUG] Frame 2287 - Object 189 Previous Position: (1202.0, 723.0) -> Current Position: (1198.0, 722.0)
# [DEBUG] Object 189 - Acceleration 너무 큼: 108.46m/s² → 100으로 제한
# [DEBUG] Object 189 - Distance: 0.12m, Speed: 3.62m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 193, Updated Class ID: 2.0
# [DEBUG] Frame 2287 - Object 193 Previous Position: (538.0, 904.0) -> Current Position: (525.0, 904.0)
# [DEBUG] Object 193 - Acceleration 너무 큼: 341.98m/s² → 100으로 제한
# [DEBUG] Object 193 - Distance: 0.38m, Speed: 11.40m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 6 cars, 1 motorcycle, 11.1ms
# Speed: 4.7ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2288 - Object 176 Previous Position: (484.0, 991.0) -> Current Position: (484.0, 991.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2288 - Object 184 Previous Position: (610.0, 743.0) -> Current Position: (607.0, 745.0)
# [DEBUG] Object 184 - Distance: 0.11m, Speed: 3.16m/s, Accel: 94.85m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 193, Updated Class ID: 2.0
# [DEBUG] Frame 2288 - Object 193 Previous Position: (525.0, 904.0) -> Current Position: (517.0, 905.0)
# [DEBUG] Object 193 - Acceleration 너무 큼: 212.09m/s² → 100으로 제한
# [DEBUG] Object 193 - Distance: 0.24m, Speed: 7.07m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2288 - Object 199 Previous Position: (1813.0, 826.0) -> Current Position: (1798.0, 825.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 395.47m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.44m, Speed: 13.18m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# Track ID: 200, Updated Class ID: 2.0
# [DEBUG] Frame 2288 - Object 200 Previous Position: (879.0, 515.0) -> Current Position: (880.0, 515.0)
# [DEBUG] Object 200 - Distance: 0.03m, Speed: 0.88m/s, Accel: 26.31m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 5 cars, 1 motorcycle, 10.7ms
# Speed: 10.5ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2289 - Object 176 Previous Position: (484.0, 991.0) -> Current Position: (483.0, 992.0)
# [DEBUG] Object 176 - Distance: 0.04m, Speed: 1.24m/s, Accel: 37.20m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2289 - Object 184 Previous Position: (607.0, 745.0) -> Current Position: (605.0, 746.0)
# [DEBUG] Object 184 - Distance: 0.07m, Speed: 1.96m/s, Accel: 58.82m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 193, Updated Class ID: 2.0
# [DEBUG] Frame 2289 - Object 193 Previous Position: (517.0, 905.0) -> Current Position: (504.0, 905.0)
# [DEBUG] Object 193 - Acceleration 너무 큼: 341.98m/s² → 100으로 제한
# [DEBUG] Object 193 - Distance: 0.38m, Speed: 11.40m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2289 - Object 199 Previous Position: (1798.0, 825.0) -> Current Position: (1791.0, 825.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 184.14m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.20m, Speed: 6.14m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
#
# 0: 384x640 5 cars, 1 motorcycle, 13.5ms
# Speed: 9.1ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2290 - Object 176 Previous Position: (483.0, 992.0) -> Current Position: (482.0, 990.0)
# [DEBUG] Object 176 - Distance: 0.07m, Speed: 1.96m/s, Accel: 58.82m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2290 - Object 184 Previous Position: (605.0, 746.0) -> Current Position: (602.0, 748.0)
# [DEBUG] Object 184 - Distance: 0.11m, Speed: 3.16m/s, Accel: 94.85m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2290 - Object 199 Previous Position: (1791.0, 825.0) -> Current Position: (1783.0, 826.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 212.09m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.24m, Speed: 7.07m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# Track ID: 200, Updated Class ID: 2.0
# [DEBUG] Frame 2290 - Object 200 Previous Position: (880.0, 515.0) -> Current Position: (879.0, 515.0)
# [DEBUG] Object 200 - Distance: 0.03m, Speed: 0.88m/s, Accel: 26.31m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 5 cars, 1 motorcycle, 17.8ms
# Speed: 4.6ms preprocess, 17.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2291 - Object 176 Previous Position: (482.0, 990.0) -> Current Position: (482.0, 990.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2291 - Object 184 Previous Position: (602.0, 748.0) -> Current Position: (599.0, 748.0)
# [DEBUG] Object 184 - Distance: 0.09m, Speed: 2.63m/s, Accel: 78.92m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 2.0
# [DEBUG] Frame 2291 - Object 189 Previous Position: (1198.0, 722.0) -> Current Position: (1182.0, 713.0)
# [DEBUG] Object 189 - Acceleration 너무 큼: 482.91m/s² → 100으로 제한
# [DEBUG] Object 189 - Distance: 0.54m, Speed: 16.10m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2291 - Object 199 Previous Position: (1783.0, 826.0) -> Current Position: (1776.0, 825.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 186.01m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.21m, Speed: 6.20m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 5 cars, 1 motorcycle, 10.8ms
# Speed: 8.8ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2292 - Object 176 Previous Position: (482.0, 990.0) -> Current Position: (484.0, 991.0)
# [DEBUG] Object 176 - Distance: 0.07m, Speed: 1.96m/s, Accel: 58.82m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2292 - Object 184 Previous Position: (599.0, 748.0) -> Current Position: (597.0, 748.0)
# [DEBUG] Object 184 - Distance: 0.06m, Speed: 1.75m/s, Accel: 52.61m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 2.0
# [DEBUG] Frame 2292 - Object 189 Previous Position: (1182.0, 713.0) -> Current Position: (1178.0, 712.0)
# [DEBUG] Object 189 - Acceleration 너무 큼: 108.46m/s² → 100으로 제한
# [DEBUG] Object 189 - Distance: 0.12m, Speed: 3.62m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2292 - Object 199 Previous Position: (1776.0, 825.0) -> Current Position: (1768.0, 825.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 210.45m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.23m, Speed: 7.01m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 200, Updated Class ID: 2.0
# [DEBUG] Frame 2292 - Object 200 Previous Position: (879.0, 515.0) -> Current Position: (879.0, 515.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 5 cars, 1 motorcycle, 10.9ms
# Speed: 3.9ms preprocess, 10.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2293 - Object 176 Previous Position: (484.0, 991.0) -> Current Position: (485.0, 993.0)
# [DEBUG] Object 176 - Distance: 0.07m, Speed: 1.96m/s, Accel: 58.82m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2293 - Object 184 Previous Position: (597.0, 748.0) -> Current Position: (595.0, 750.0)
# [DEBUG] Object 184 - Distance: 0.08m, Speed: 2.48m/s, Accel: 74.40m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 2.0
# [DEBUG] Frame 2293 - Object 189 Previous Position: (1178.0, 712.0) -> Current Position: (1174.0, 711.0)
# [DEBUG] Object 189 - Acceleration 너무 큼: 108.46m/s² → 100으로 제한
# [DEBUG] Object 189 - Distance: 0.12m, Speed: 3.62m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 199, Updated Class ID: 2.0
# [DEBUG] Frame 2293 - Object 199 Previous Position: (1768.0, 825.0) -> Current Position: (1761.0, 825.0)
# [DEBUG] Object 199 - Acceleration 너무 큼: 184.14m/s² → 100으로 제한
# [DEBUG] Object 199 - Distance: 0.20m, Speed: 6.14m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 200, Updated Class ID: 2.0
# [DEBUG] Frame 2293 - Object 200 Previous Position: (879.0, 515.0) -> Current Position: (879.0, 516.0)
# [DEBUG] Object 200 - Distance: 0.03m, Speed: 0.88m/s, Accel: 26.31m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 5 cars, 1 motorcycle, 27.1ms
# Speed: 6.6ms preprocess, 27.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2294 - Object 176 Previous Position: (485.0, 993.0) -> Current Position: (485.0, 994.0)
# [DEBUG] Object 176 - Distance: 0.03m, Speed: 0.88m/s, Accel: 26.31m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# [DEBUG] Frame 2294 - Object 184 Previous Position: (595.0, 750.0) -> Current Position: (593.0, 751.0)
# [DEBUG] Object 184 - Distance: 0.07m, Speed: 1.96m/s, Accel: 58.82m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 189, Updated Class ID: 2.0
# [DEBUG] Frame 2294 - Object 189 Previous Position: (1174.0, 711.0) -> Current Position: (1171.0, 709.0)
# ...
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 3 cars, 2 motorcycles, 14.4ms
# Speed: 3.3ms preprocess, 14.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2400 - Object 176 Previous Position: (546.0, 985.0) -> Current Position: (551.0, 984.0)
# [DEBUG] Object 176 - Acceleration 너무 큼: 134.13m/s² → 100으로 제한
# [DEBUG] Object 176 - Distance: 0.15m, Speed: 4.47m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# Track ID: 205, Updated Class ID: 2.0
# [DEBUG] Frame 2400 - Object 205 Previous Position: (897.0, 872.0) -> Current Position: (885.0, 871.0)
# [DEBUG] Object 205 - Acceleration 너무 큼: 316.77m/s² → 100으로 제한
# [DEBUG] Object 205 - Distance: 0.35m, Speed: 10.56m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 206, Updated Class ID: 2.0
# [DEBUG] Frame 2400 - Object 206 Previous Position: (1126.0, 712.0) -> Current Position: (1123.0, 710.0)
# [DEBUG] Object 206 - Distance: 0.11m, Speed: 3.16m/s, Accel: 94.85m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 3 cars, 2 motorcycles, 12.7ms
# Speed: 5.2ms preprocess, 12.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2401 - Object 176 Previous Position: (551.0, 984.0) -> Current Position: (554.0, 983.0)
# [DEBUG] Object 176 - Distance: 0.09m, Speed: 2.77m/s, Accel: 83.19m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# Track ID: 205, Updated Class ID: 2.0
# [DEBUG] Frame 2401 - Object 205 Previous Position: (885.0, 871.0) -> Current Position: (873.0, 870.0)
# [DEBUG] Object 205 - Acceleration 너무 큼: 316.77m/s² → 100으로 제한
# [DEBUG] Object 205 - Distance: 0.35m, Speed: 10.56m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 206, Updated Class ID: 2.0
# [DEBUG] Frame 2401 - Object 206 Previous Position: (1123.0, 710.0) -> Current Position: (1118.0, 708.0)
# [DEBUG] Object 206 - Acceleration 너무 큼: 141.66m/s² → 100으로 제한
# [DEBUG] Object 206 - Distance: 0.16m, Speed: 4.72m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 3 cars, 2 motorcycles, 10.8ms
# Speed: 3.6ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2402 - Object 176 Previous Position: (554.0, 983.0) -> Current Position: (559.0, 982.0)
# [DEBUG] Object 176 - Acceleration 너무 큼: 134.13m/s² → 100으로 제한
# [DEBUG] Object 176 - Distance: 0.15m, Speed: 4.47m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# Track ID: 205, Updated Class ID: 2.0
# [DEBUG] Frame 2402 - Object 205 Previous Position: (873.0, 870.0) -> Current Position: (860.0, 869.0)
# [DEBUG] Object 205 - Acceleration 너무 큼: 342.99m/s² → 100으로 제한
# [DEBUG] Object 205 - Distance: 0.38m, Speed: 11.43m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 206, Updated Class ID: 2.0
# [DEBUG] Frame 2402 - Object 206 Previous Position: (1118.0, 708.0) -> Current Position: (1115.0, 705.0)
# [DEBUG] Object 206 - Acceleration 너무 큼: 111.61m/s² → 100으로 제한
# [DEBUG] Object 206 - Distance: 0.12m, Speed: 3.72m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 2 cars, 2 motorcycles, 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2403 - Object 176 Previous Position: (559.0, 982.0) -> Current Position: (564.0, 982.0)
# [DEBUG] Object 176 - Acceleration 너무 큼: 131.53m/s² → 100으로 제한
# [DEBUG] Object 176 - Distance: 0.15m, Speed: 4.38m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# Track ID: 205, Updated Class ID: 2.0
# [DEBUG] Frame 2403 - Object 205 Previous Position: (860.0, 869.0) -> Current Position: (850.0, 866.0)
# [DEBUG] Object 205 - Acceleration 너무 큼: 274.64m/s² → 100으로 제한
# [DEBUG] Object 205 - Distance: 0.31m, Speed: 9.15m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 206, Updated Class ID: 2.0
# [DEBUG] Frame 2403 - Object 206 Previous Position: (1115.0, 705.0) -> Current Position: (1111.0, 704.0)
# [DEBUG] Object 206 - Acceleration 너무 큼: 108.46m/s² → 100으로 제한
# [DEBUG] Object 206 - Distance: 0.12m, Speed: 3.62m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
#
# 0: 384x640 3 cars, 2 motorcycles, 12.0ms
# Speed: 3.7ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Track ID: 176, Updated Class ID: 2.0
# [DEBUG] Frame 2404 - Object 176 Previous Position: (564.0, 982.0) -> Current Position: (567.0, 982.0)
# [DEBUG] Object 176 - Distance: 0.09m, Speed: 2.63m/s, Accel: 78.92m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 184, Updated Class ID: 2.0
# Track ID: 205, Updated Class ID: 2.0
# [DEBUG] Frame 2404 - Object 205 Previous Position: (850.0, 866.0) -> Current Position: (839.0, 865.0)
# [DEBUG] Object 205 - Acceleration 너무 큼: 290.56m/s² → 100으로 제한
# [DEBUG] Object 205 - Distance: 0.32m, Speed: 9.69m/s, Accel: 100.00m/s²
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Track ID: 206, Updated Class ID: 2.0
# [DEBUG] Frame 2404 - Object 206 Previous Position: (1111.0, 704.0) -> Current Position: (1109.0, 702.0)
# [DEBUG] Object 206 - Distance: 0.08m, Speed: 2.48m/s, Accel: 74.40m/s²
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# YOLO Output (x_center, y_center, width, height): (0.467187, 0.759722, 0.8375, 0.515741)
# Converted Pixel BBox: (92.99904000000001, 522.99972, 1700.99904, 1080.0)
# YOLO Output (x_center, y_center, width, height): (0.39974, 0.538426, 0.067187, 0.152778)
# Converted Pixel BBox: (703.00128, 498.99996, 832.00032, 664.0002)
# YOLO Output (x_center, y_center, width, height): (0.810417, 0.805093, 0.141667, 0.171296)
# Converted Pixel BBox: (1420.00032, 777.0005999999998, 1692.00096, 962.00028)
# Log data saved to: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Log data/1800-1830_logA.csv
# Interval data saved to: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Interval data/1800-1830_intervalA.csv

# %%
### x축 거리 차 +density 추가


import math
import cv2
import os
import numpy as np
import pandas as pd
from collections import Counter

# YOLO 모델 로드
model_weight_path = "/content/drive/MyDrive/Capstone/best_motorcycle_detector_DAY&NIGHT8.pt"
model = YOLO(model_weight_path)
model.to('cuda')  # GPU 사용

# DeepSORT 초기화
### DeepSORTWrapper와 Mars
tracker = DeepSortWrapper(model_filename= mars_small128, max_cosine_distance=0.2, nn_budget=None)
print("YOLO model and Deep SORT wrapper initialized.")

# 전역 변수 정의
log_data = []
interval_data = []
detected_classes = []
object_data = {}
object_directions = {}
pair_code_map = {}  # Pair Code 매핑
pair_code_counter = 1  # Pair Code 생성용
object_class_counts = {}

frame_counter = 0
pixel_to_meter_ratio = None
density_per_frame = {}

# 영역 정의 (YOLO 형식)
right_turn_zone_yolo = (0.399740, 0.538426, 0.067187, 0.152778)
straight_zone_yolo = (0.810417, 0.805093, 0.141667, 0.171296)
interval_zone_yolo = (0.399219, 0.706481, 0.789062, 0.431481)
finish_zone_yolo = (0.044271, 0.858333, 0.081250, 0.211111)
actual_interval_width = 47.0  # 실제 평가 거리 (미터)

# 고유 ID 생성 및 유지
# def get_unique_id(track_id):
#     if track_id not in unique_ids:
#         unique_ids[track_id] = str(uuid.uuid4())[:8]
#     return unique_ids[track_id]

# 픽셀-to-미터 변환 비율 계산
def calculate_pixel_to_meter_ratio(frame_width):
    interval_width_pixels = interval_zone_yolo[2] * frame_width
    if interval_width_pixels < 1:
        print("Error: interval_width_pixels is 0, check interval_zone_yolo values.")
        return 1.0  # 혹은 기본값 설정
    pixel_to_meter_ratio = actual_interval_width / interval_width_pixels

    if pixel_to_meter_ratio < 0.01:
        print(f"[DEBUG] pixel_to_meter_ratio 값이 너무 작아 기본값(0.1)로 설정합니다.")
        pixel_to_meter_ratio = 0.1

    # print(f"[DEBUG] Pixel-to-Meter Ratio : {pixel_to_meter_ratio}")
    return pixel_to_meter_ratio

# YOLO 형식의 좌표를 픽셀 좌표로 변환
def yolo_to_pixel(label, img_width, img_height, max_size=2000):
    # YOLO format: (x_center, y_center, width, height)
    x_center, y_center, width, height = label

    # 상대 좌표를 픽셀 좌표로 변환
    x1 = (x_center - width / 2) * img_width
    x2 = (x_center + width / 2) * img_width
    y1 = (y_center - height / 2) * img_height
    y2 = (y_center + height / 2) * img_height

    # 바운딩 박스 크기가 너무 커지지 않도록 제한
    width_pixels = max(0, min(max_size, x2 - x1))
    height_pixels = max(0, min(max_size, y2 - y1))

    # 좌표 범위 보정
    x1 = max(0, min(x1, img_width - width_pixels))
    x2 = x1 + width_pixels
    y1 = max(0, min(y1, img_height - height_pixels))
    y2 = y1 + height_pixels

    # 디버깅 출력
    #print(f"YOLO Output (x_center, y_center, width, height): {label}")
    #print(f"Converted Pixel BBox: ({x1}, {y1}, {x2}, {y2})")

    return (int(x1), int(y1), int(x2), int(y2))

# BBox가 특정 Zone과 교차 또는 포함되는지 확인
def is_bbox_in_zone(bbox, zone):
    (x1, y1, x2, y2) = bbox
    (z_x1, z_y1, z_x2, z_y2) = zone
    return not (x2 < z_x1 or x1 > z_x2 or y2 < z_y1 or y1 > z_y2)

# BBox를 기준으로 차량의 방향(우회전/직진)을 분류
def classify_direction(bbox, frame_width, frame_height):
    right_turn_zone = yolo_to_pixel(right_turn_zone_yolo, frame_width, frame_height)
    straight_zone = yolo_to_pixel(straight_zone_yolo, frame_width, frame_height)

    if is_bbox_in_zone(bbox, right_turn_zone):
        return "우회전"
    elif is_bbox_in_zone(bbox, straight_zone):
        return "직진"
    return "미정"

def calculate_angle(dx, dy):
    if dx == 0:
        return 90 if dy > 0 else -90  # 위쪽 이동(90도), 아래쪽 이동(-90도)
    return math.degrees(math.atan2(dy, dx))
# import math

# def calculate_angle(dx, dy):
#     """
#     이동 벡터 (dx, dy)를 이용해 각도를 계산하는 함수.
#     :param dx: X축 이동 거리
#     :param dy: Y축 이동 거리
#     :return: 이동 각도 (degree)
#     """
#     angle = math.degrees(math.atan2(dy, dx))  # atan2는 (-180 ~ 180) 범위 반환
#     return angle



def determine_movement_direction(track_id, current_position):
    """
    객체의 이동 벡터를 계산하고, 실제 이동 방향을 분석하여 반환하는 함수.
    - 수평(왼쪽) 이동 → "직진"
    - 아래쪽 이동 → "우회전"
    - 그 외 → "미정"

    :param track_id: 객체의 고유 추적 ID
    :param current_position: 현재 프레임에서의 객체 중심점 (x, y)
    :return: 이동 방향 ("직진", "우회전", "미정")
    """
    if track_id in object_data:
        prev_position = object_data[track_id]["position"]

        # 이동 벡터 계산
        dx = current_position[0] - prev_position[0]  # X축 이동 거리
        dy = current_position[1] - prev_position[1]  # Y축 이동 거리

        # 이동 방향 각도 계산
       # angle = calculate_angle(dx, dy)

        # ✅ 이동 방향 판별
        if dx < 0:  # 왼쪽 방향 (거의 수평 이동)
            direction = "직진"
        elif dy > 0:  # 아래쪽 이동 → 우회전 가능
            direction = "우회전"
        else:
            direction = "미정"  # 방향을 알 수 없는 경우

        # 객체 데이터 업데이트 (현재 위치를 새로운 기준점으로 저장)
        object_data[track_id] = {"position": current_position, "direction": direction}

        return direction
    else:
        # 처음 감지된 객체 → "미정" 상태로 설정
        object_data[track_id] = {"position": current_position, "direction": "미정"}
        return "미정"

# 이동 거리, 속도, 가속도 계산
import numpy as np


def calculate_motion(object_id, current_position, fps, pixel_to_meter_ratio):
    if object_id in object_data:
        prev_data = object_data[object_id]
        prev_pos = prev_data.get("position",current_position)
        prev_distance = prev_data.get("distance",0.0)
        prev_speed = prev_data.get("speed",0.0)

        # 이전 위치가 현재 위치와 동일하면 거리 계산 제외
        #if np.array_equal(prev_pos, current_position):
        #    print(f"[DEBUG] Object {object_id} did not move.")
        #    return 0.0, prev_speed, 0.0


        # 거리 및 속도 계산
        dx = current_position[0]-prev_pos[0]
        dy = current_position[1]-prev_pos[1]
        distance_pixels = np.linalg.norm([dx,dy])

        distance_meters = prev_distance + (distance_pixels * pixel_to_meter_ratio)
        speed = distance_meters * fps
        acceleration = (speed - prev_speed) * fps

        # 가속도가 비정상적으로 클 경우 제한
        if acceleration > 100:
            print(f"[DEBUG] Object {object_id} - Acceleration 너무 큼: {acceleration:.2f}m/s² → 100으로 제한")
            acceleration = 100
                # 이동이 감지되지 않으면 로그를 남기지 않음

        if distance_meters < 0.01:
            return 0.0, prev_speed, 0.0  # 🔹 작은 이동은 무시

        # 디버깅 정보 출력
        #print(f"[DEBUG] Object {object_id} - Distance: {distance_meters:.2f}m, Speed: {speed:.2f}m/s, Accel: {acceleration:.2f}m/s²")

        # 객체 정보 업데이트
        object_data[object_id] = {"position": current_position, "distance": distance_meters, "speed": speed}
        return distance_meters, speed, acceleration

    else:
        # 객체가 처음 등장했을 때 초기화
        object_data[object_id] = {"position": current_position,"distance":0.0, "speed": 0.0}
        #print(f"[DEBUG] Object {object_id} initialized.")
        return 0.0, 0.0, 0.0


# 객체 클래스 변경 함수
def update_object_class(track_id, new_class):
    track_id = str(track_id)

    if track_id not in object_class_counts:
        object_class_counts[track_id] = Counter()

    # 새로운 클래스를 카운트
    object_class_counts[track_id][new_class] += 1

    # 가장 빈도가 높은 클래스를 가져옴
    most_common_class = object_class_counts[track_id].most_common(1)[0][0]
    #print(f"[DEBUG] Object ID {track_id} - Most Common Class: {most_common_class}")
    class_label = "car" if most_common_class == 2 else "motorcycle"

    # 객체의 클래스가 결정되면 모든 프레임에서 해당 클래스를 업데이트
    for obj in log_data:
        if obj["Object ID"] == track_id:
            obj["Class"] = class_label

    # interval_data에도 반영 (추가된 부분)
    for interval in interval_data:
        if interval["Object 1 ID"] == track_id:
            interval["Object 1 Class"] = class_label
        if interval["Object 2 ID"] == track_id:
            interval["Object 2 Class"] = class_label
    return most_common_class

    # 추가로 객체 정보 갱신
    for track in tracker.tracks:
        if track.track_id == track_id:
            track.class_id = most_common_class

    return most_common_class

# Interval 데이터 생성
def update_interval_data(frame_num, log_data, pixel_to_meter_ratio):
    global interval_data, pair_code_map, pair_code_counter

    right_turn_vehicles = [obj for obj in log_data if obj["Direction"] == "우회전"]
    straight_vehicles = [obj for obj in log_data if obj["Direction"] == "직진" or obj["Direction"]=="미정"]

    for obj1 in right_turn_vehicles:
        for obj2 in straight_vehicles:
            if not obj1.get("Object ID") or not obj2.get("Object ID"):
                continue

            if obj1["Class"] in ["bus","truck"] or obj2["Class"] in ["bus","truck"]:
                continue

            # 중심점 거리 계산
            #center1 = ((obj1["BBox"][0] + obj1["BBox"][2]) / 2, (obj1["BBox"][1] + obj1["BBox"][3]) / 2)
            #center2 = ((obj2["BBox"][0] + obj2["BBox"][2]) / 2, (obj2["BBox"][1] + obj2["BBox"][3]) / 2)
            lag_spacing_pixels = abs(obj1["BBox"][0] - obj2["BBox"][0])
            lag_spacing_meters = lag_spacing_pixels * pixel_to_meter_ratio

            # 고유 Pair Code 생성 및 관리
            pair_key = (obj1["Object ID"], obj2["Object ID"])
            if pair_key not in pair_code_map:
                pair_code_map[pair_key] = pair_code_counter
                pair_code_counter += 1

            interval_data.append({
                "Frame": frame_num,
                "Object 1 ID": obj1["Object ID"],
                "Object 2 ID": obj2["Object ID"],
                "Pair Code": pair_code_map[pair_key],
                "Lag Spacing (m)": lag_spacing_meters,
                "Object 1 Speed (m/s)": obj1["Speed (m/s)"],
                "Object 2 Speed (m/s)": obj2["Speed (m/s)"],
                "Object 1 Class": obj1["Class"],
                "Object 2 Class": obj2["Class"],
                "Density": density_per_frame.get(frame_num,0)
            })

# YOLO 결과를 DeepSORT 입력으로 변환
def yolo_to_deepsort(yolo_results, target_classes):
    detections = []
    classes = []
    for det in yolo_results[0].boxes:
        x1, y1, x2, y2 = map(float, det.xyxy[0].cpu().numpy())
        confidence = float(det.conf.cpu().numpy().item())
        class_id = int(det.cls.cpu().numpy())
        if class_id in target_classes:
            detections.append([(x1, y1, x2, y2), confidence])
            classes.append(class_id)

            # 디버깅 로그 추가: YOLO에서 DeepSORT로 전달되는 바운딩 박스 및 신뢰도 출력
            #print(f"YOLO to DeepSORT - BBox: ({x1}, {y1}, {x2}, {y2}), Confidence: {confidence}, Class ID: {class_id}")

    return detections, classes

# 객체 클래스별 색상 반환 함수
def get_class_color(class_id):
    if class_id == 2:  # car
        return (0, 255, 0)  # 초록 (BGR)
    else:
        return (255, 0, 0)  # 파랑 (BGR)

# 수정된 메인 루프

if __name__ == "__main__":
    target_classes = [2, 3]  # car(2), motorcycle(3)

    video_path = "/content/drive/MyDrive/Capstone/11.15 1800-2000/11.15 1930-2000 - 필터링.mp4"
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
      print(f"Error: Unable to open video file {video_path}")

    fps = int(cap.get(cv2.CAP_PROP_FPS))

    if fps <= 0 or fps > 60:
      #print(f"[DEBUG] FPS 값이 비정상적({fps}), 기본값(30)으로 설정합니다.")
      fps = 30

    #print(f"[DEBUG] FPS: {fps}")

    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    if frame_width == 0 or frame_height == 0:
      print("Error: Invalid video frame dimensions")

    pixel_to_meter_ratio = calculate_pixel_to_meter_ratio(frame_width)

    output_directory = "/content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Log video"
    import os
    output_video_path = os.path.join(output_directory, '11.15 1930-2000_processed_video.avi')
    video_writer = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*'MJPG'), fps, (frame_width, frame_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_counter += 1

        # YOLO 객체 검출
        results = model(frame, conf=0.3)

        valid_classes = {2:"car",3:"motorcycle"}
        class_counts = {"car":0,"motorcycle":0}

        # YOLO 결과를 DeepSORT로 변환
        detected_classes.clear()
        all_detections = []

        for r in results:
            for box in r.boxes.data.tolist():
              x1, y1, x2, y2, score, class_id = box
              if score >= 0.5:
                class_name = valid_classes[int(class_id)]
                class_counts[class_name] = class_counts.get(class_name, 0) + 1

                bbox = (int(x1), int(y1), int(x2), int(y2))
                if is_bbox_in_zone(bbox, yolo_to_pixel(interval_zone_yolo, frame_width, frame_height)):
                    all_detections.append([int(x1),int(y1),int(x2),int(y2),float(score)])
                    detected_classes.append(int(class_id))

                if class_id in [2,3,5,7]:
                    density_per_frame[frame_counter] = density_per_frame.get(frame_counter, 0) + 1

        # Ensure detected_classes and tracker.tracks have the same length
        if len(all_detections) != len(detected_classes):
            print(f"Warning: Mismatch between detections ({len(all_detections)}) and detected classes ({len(detected_classes)})")

        # DeepSORTWrapper로 추적
        tracker.update(frame, all_detections)
        if not detected_classes:
            print("Warning: No detected classes were found, skipping classification.")

        current_log_data = []
        for track, detected_class_id in zip(tracker.tracks,detected_classes):
            track_id = track.track_id
            x1, y1, x2, y2 = track.bbox

            # DeepSORT에서 제공하는 track_id를 사용하여 class_id를 가져옴
            #class_id = update_object_class(track_id, 2)  # 기본값 2(car)로 설정

            # 디버깅: 클래스 ID와 색상 확인
            #print(f"Track ID: {track_id}, Updated Class ID: {class_id}")

            updated_class_id = update_object_class(track_id, detected_class_id)

            color = get_class_color(updated_class_id)  # 🔹 color 변수 정의 추가

            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)

            if f"ID {track_id}" not in log_data:
                label = "car" if updated_class_id == 2 else "motorcycle"
                direction = object_directions.get(track_id, "미정")

                cv2.putText(frame, f"{label} ID {track_id} {direction}",
                            (int(x1), int(y1) - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)


            # 바운딩 박스 x좌표가 음수인 경우, 추적 중단
            if x1 < 0 or y1 < 0 or x2 < 0 or y2 < 0:
                continue

            current_position = ((x1 + x2) // 2, (y1 + y2) // 2)
            #print(f"[DEBUG] Frame {frame_counter} - Object {track_id} Previous Position: {object_data.get(track_id, {}).get('position', 'N/A')} -> Current Position: {current_position}")

            #unique_id = get_unique_id(track_id)



            # 이동 거리, 속도, 가속도 계산
            distance, speed, acceleration = calculate_motion(track_id, current_position, fps, pixel_to_meter_ratio)

            # 이동 벡터를 기반으로 실제 이동 방향 결정
            direction = determine_movement_direction(track_id, current_position)

            bbox = (int(x1), int(y1), int(x2), int(y2))

            # 방향 분류
            direction = object_directions.get(track_id, "미정")
            if direction == "미정":
                direction = classify_direction(bbox, frame_width, frame_height)
                object_directions[track_id] = direction

            # 로그 데이터 기록
            bbox = (int(x1), int(y1), int(x2), int(y2))

            #if not any(obj["Object ID"] == track_id for obj in log_data):
            if is_bbox_in_zone(bbox, yolo_to_pixel(interval_zone_yolo, frame_width, frame_height)):
                direction = classify_direction(bbox, frame_width, frame_height)
                updated_class_id = update_object_class(track_id, detected_class_id)

                obj_data = {
                    "Frame": frame_counter,
                    "Object ID": track_id,
                    "Class": "car" if updated_class_id == 2 else "motorcycle" ,
                    "Distance (m)": distance,
                    "Speed (m/s)": speed,
                    "Acceleration (m/s^2)": acceleration,
                    "Direction": direction,
                    "BBox": (x1, y1, x2, y2),
                    "Density" : density_per_frame.get(frame_counter,0)
                }
            log_data.append(obj_data)
            current_log_data.append(obj_data)

            # 화면 표시
            label = "car" if updated_class_id == 2 else "motorcycle"
            color = get_class_color(updated_class_id)
#            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, f"{label} ID {track_id} {direction}", (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,color, 2)

        # Interval 데이터 업데이트
        update_interval_data(frame_counter, current_log_data, pixel_to_meter_ratio)

        if not video_writer.isOpened():
            print("Error: VideoWriter failed to open.")

        if frame is None:
            print(f"Error: Empty frame at {frame_counter}")




        # 비디오 저장
        video_writer.write(frame)
        # 객체 ID 및 바운딩 박스 정보 로그 출력
        #print(f"Object ID: {unique_id}, BBox: ({x1}, {y1}, {x2}, {y2}), Direction: {direction}")


    # 데이터 저장
    log_data_path = "/content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Log data/1930-2000_log3.csv"
    interval_data_path = "/content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Interval data/1930-2000_interval3.csv"
    pd.DataFrame(log_data).to_csv(log_data_path, index=False)
    pd.DataFrame(interval_data).to_csv(interval_data_path, index=False)


    print(f"Log data saved to: {log_data_path}")
    print(f"Interval data saved to: {interval_data_path}")

    cap.release()
    video_writer.release()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Speed: 7.1ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.3ms
# Speed: 8.6ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 124.87m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 18.8ms
# Speed: 12.4ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 12.4ms
# Speed: 11.3ms preprocess, 12.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 16.2ms
# Speed: 7.8ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 162.80m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 14.1ms
# Speed: 3.9ms preprocess, 14.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 15.2ms
# Speed: 3.4ms preprocess, 15.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 530.50m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.0ms
# Speed: 3.9ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 113 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.1ms
# Speed: 3.5ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 12.0ms
# Speed: 4.3ms preprocess, 12.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 10.9ms
# Speed: 9.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 124.87m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.7ms
# Speed: 6.7ms preprocess, 11.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 13.0ms
# Speed: 4.3ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 12.8ms
# Speed: 9.6ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.6ms
# Speed: 3.8ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.1ms
# Speed: 3.9ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 12.1ms
# Speed: 4.9ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.3ms
# Speed: 10.2ms preprocess, 11.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 113 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 13.0ms
# Speed: 5.3ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 12.3ms
# Speed: 4.5ms preprocess, 12.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.0ms
# Speed: 7.0ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 364.04m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 364.04m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.8ms
# Speed: 3.8ms preprocess, 11.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 139.60m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 12.3ms
# Speed: 5.6ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.2ms
# Speed: 4.5ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 13.9ms
# Speed: 6.3ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 19.2ms
# Speed: 4.0ms preprocess, 19.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 614.26m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 14.1ms
# Speed: 4.4ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 162.80m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 11.0ms
# Speed: 3.9ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 11.4ms
# Speed: 3.7ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 558.42m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 11.2ms
# Speed: 4.6ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.1ms
# Speed: 3.6ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.2ms
# Speed: 3.5ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.4ms
# Speed: 3.9ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.1ms
# Speed: 3.6ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 motorcycle, 13.5ms
# Speed: 3.9ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 670.10m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 13.5ms
# Speed: 3.3ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 16.8ms
# Speed: 7.7ms preprocess, 16.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 257.42m/s² → 100으로 제한
# [DEBUG] Object 116 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 13.0ms
# Speed: 4.6ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 112 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 13.7ms
# Speed: 3.9ms preprocess, 13.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 586.34m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.5ms
# Speed: 8.1ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 362.97m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 10.9ms
# Speed: 8.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.0ms
# Speed: 8.0ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.3ms
# Speed: 3.5ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.3ms
# Speed: 3.5ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 364.04m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 5699.20m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 12.3ms
# Speed: 3.8ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 12.1ms
# Speed: 3.2ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 11.5ms
# Speed: 4.3ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 362.97m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 11.1ms
# Speed: 6.5ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 11.0ms
# Speed: 10.0ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 11.3ms
# Speed: 4.7ms preprocess, 11.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 10.9ms
# Speed: 3.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 12.9ms
# Speed: 4.1ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 10.9ms
# Speed: 3.8ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.9ms
# Speed: 8.2ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 11.9ms
# Speed: 4.7ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.5ms
# Speed: 3.4ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 11.4ms
# Speed: 3.6ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 1 motorcycle, 14.0ms
# Speed: 3.7ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 391.89m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.2ms
# Speed: 3.6ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 16.4ms
# Speed: 5.0ms preprocess, 16.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.5ms
# Speed: 5.0ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 362.97m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.0ms
# Speed: 10.1ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 362.97m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 14.0ms
# Speed: 3.6ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.3ms
# Speed: 4.8ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 12.5ms
# Speed: 3.8ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 14.2ms
# Speed: 3.5ms preprocess, 14.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 13.8ms
# Speed: 5.7ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 12.8ms
# Speed: 4.0ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 390.89m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 13.3ms
# Speed: 4.1ms preprocess, 13.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 364.04m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 11.2ms
# Speed: 6.7ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 364.04m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 12.0ms
# Speed: 4.9ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 364.04m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 11.2ms
# Speed: 4.0ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 11.1ms
# Speed: 4.2ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 11.0ms
# Speed: 6.7ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 391.89m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 12.5ms
# Speed: 6.8ms preprocess, 12.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 11.3ms
# Speed: 4.4ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 12.2ms
# Speed: 3.7ms preprocess, 12.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.6ms
# Speed: 4.4ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 362.97m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 225.10m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 12.3ms
# Speed: 8.2ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.0ms
# Speed: 8.7ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 20.0ms
# Speed: 10.4ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 362.97m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 19.5ms
# Speed: 3.5ms preprocess, 19.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 16.7ms
# Speed: 6.3ms preprocess, 16.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 362.97m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 312.16m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 13.8ms
# Speed: 8.7ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 195.45m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 16.9ms
# Speed: 3.9ms preprocess, 16.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 14.7ms
# Speed: 3.8ms preprocess, 14.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 14.1ms
# Speed: 8.2ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 116 - Acceleration 너무 큼: 364.04m/s² → 100으로 제한
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 18.8ms
# Speed: 7.0ms preprocess, 18.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 21.1ms
# Speed: 3.6ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.2ms
# Speed: 3.7ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.0ms
# Speed: 4.3ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 588.99m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 19.5ms
# Speed: 3.5ms preprocess, 19.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 5.9ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 16.5ms
# Speed: 7.6ms preprocess, 16.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 644.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 17.0ms
# Speed: 11.5ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 16.9ms
# Speed: 3.7ms preprocess, 16.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 559.11m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 20.5ms
# Speed: 3.6ms preprocess, 20.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.2ms
# Speed: 4.3ms preprocess, 15.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 23.3ms
# Speed: 7.8ms preprocess, 23.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 19.1ms
# Speed: 6.8ms preprocess, 19.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 19.0ms
# Speed: 5.6ms preprocess, 19.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 13.8ms
# Speed: 3.7ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.7ms
# Speed: 8.6ms preprocess, 12.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 1369.26m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 14.6ms
# Speed: 5.9ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 225.10m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 406.53m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 14.4ms
# Speed: 3.9ms preprocess, 14.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.8ms
# Speed: 3.5ms preprocess, 15.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.8ms
# Speed: 8.3ms preprocess, 12.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 7.7ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 3.8ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.3ms
# Speed: 11.6ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 14.1ms
# Speed: 7.8ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.3ms
# Speed: 4.1ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 10.2ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 225.10m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 9.5ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 3.6ms preprocess, 11.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.6ms
# Speed: 3.9ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 225.10m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 14.8ms
# Speed: 3.6ms preprocess, 14.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 13.1ms
# Speed: 3.7ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.5ms
# Speed: 4.2ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 257.42m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 8.9ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.7ms
# Speed: 4.1ms preprocess, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.2ms
# Speed: 4.3ms preprocess, 12.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 225.10m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.5ms
# Speed: 3.4ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.1ms
# Speed: 4.7ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 5.8ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 16.5ms
# Speed: 3.9ms preprocess, 16.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.4ms
# Speed: 5.8ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 312.16m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 318.35m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 169.84m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 7.6ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.6ms
# Speed: 3.9ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 257.42m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 10.6ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 3.4ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 3.8ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.4ms
# Speed: 3.9ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 225.10m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 3.6ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 3.7ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.9ms
# Speed: 3.8ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 5.3ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 264.88m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 339.67m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 4.7ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 10.0ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 10.9ms
# Speed: 6.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.8ms
# Speed: 3.6ms preprocess, 11.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 4.9ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.6ms
# Speed: 3.1ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 225.10m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 9.6ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.8ms
# Speed: 3.7ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 13.2ms
# Speed: 11.0ms preprocess, 13.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 9.1ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 8.1ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.7ms
# Speed: 3.6ms preprocess, 11.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 3.9ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.0ms
# Speed: 5.4ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 13.5ms
# Speed: 3.8ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 1117.18m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.4ms
# Speed: 3.5ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 10.9ms
# Speed: 3.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 257.42m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.1ms
# Speed: 4.0ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 6.2ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 1034.58m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.8ms
# Speed: 3.5ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 12.5ms
# Speed: 4.8ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.8ms
# Speed: 3.6ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 447.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.8ms
# Speed: 4.6ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.6ms
# Speed: 4.1ms preprocess, 12.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 670.10m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 13.5ms
# Speed: 3.7ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 3.5ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 446.73m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.0ms
# Speed: 4.7ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 10.9ms
# Speed: 10.1ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 117 - Acceleration 너무 큼: 225.10m/s² → 100으로 제한
# [DEBUG] Object 118 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.9ms
# Speed: 8.3ms preprocess, 11.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 118 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.6ms
# Speed: 3.6ms preprocess, 12.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 118 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 19.7ms
# Speed: 3.7ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 118 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.6ms
# Speed: 5.3ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 118 - Acceleration 너무 큼: 230.24m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 14.5ms
# Speed: 5.6ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 11.2ms
# Speed: 4.0ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 118 - Acceleration 너무 큼: 474.65m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 9.0ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 118 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.7ms
# Speed: 4.4ms preprocess, 11.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 118 - Acceleration 너무 큼: 139.60m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 3.8ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 118 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.3ms
# Speed: 11.5ms preprocess, 11.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 15.5ms
# Speed: 4.0ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 13.0ms
# Speed: 3.6ms preprocess, 13.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 13.0ms
# Speed: 7.8ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 12.3ms
# Speed: 3.7ms preprocess, 12.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 120 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 20.7ms
# Speed: 4.0ms preprocess, 20.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 120 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 17.2ms
# Speed: 3.5ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 120 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 20.4ms
# Speed: 3.6ms preprocess, 20.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 120 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 2 motorcycles, 15.0ms
# Speed: 3.7ms preprocess, 15.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 120 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 2 motorcycles, 15.3ms
# Speed: 6.3ms preprocess, 15.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 120 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 2 motorcycles, 13.4ms
# Speed: 3.7ms preprocess, 13.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 120 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 2 motorcycles, 24.2ms
# Speed: 5.0ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 120 - Acceleration 너무 큼: 308.40m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 12.9ms
# Speed: 3.7ms preprocess, 12.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 113 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 120 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 26.4ms
# Speed: 8.6ms preprocess, 26.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 113 - Acceleration 너무 큼: 124.87m/s² → 100으로 제한
# [DEBUG] Object 120 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 11.2ms
# ...
# [DEBUG] Object 163 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 157.94m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.0ms
# Speed: 5.5ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 14.8ms
# Speed: 3.7ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 139.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.0ms
# Speed: 7.7ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 139.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.2ms
# Speed: 3.8ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 139.60m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 307.13m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.4ms
# Speed: 4.1ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 150.36m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 19.0ms
# Speed: 3.7ms preprocess, 19.0ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 195.45m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 16.9ms
# Speed: 3.9ms preprocess, 16.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 257.42m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 124.87m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 17.3ms
# Speed: 3.7ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 257.42m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 14.3ms
# Speed: 3.4ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 284.74m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 162.80m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 15.2ms
# Speed: 3.7ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 150.36m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 17.2ms
# Speed: 4.7ms preprocess, 17.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 150.36m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 12.7ms
# Speed: 9.8ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 336.21m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 21.8ms
# Speed: 6.3ms preprocess, 21.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 225.10m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 13.4ms
# Speed: 5.9ms preprocess, 13.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 203.27m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 139.60m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 203.27m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 13.4ms
# Speed: 5.6ms preprocess, 13.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 150.36m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 2 motorcycles, 11.4ms
# Speed: 6.5ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 150.36m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 2 motorcycles, 13.1ms
# Speed: 3.1ms preprocess, 13.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 169.84m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 176.59m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 169.84m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 14.8ms
# Speed: 3.9ms preprocess, 14.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 230.24m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 364.04m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 12.6ms
# Speed: 3.6ms preprocess, 12.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 142.37m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 17.1ms
# Speed: 3.4ms preprocess, 17.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 161 - Acceleration 너무 큼: 150.36m/s² → 100으로 제한
# [DEBUG] Object 166 - Acceleration 너무 큼: 139.60m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 11.0ms
# Speed: 3.9ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 280.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 10.9ms
# Speed: 10.8ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 195.45m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 13.4ms
# Speed: 5.3ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.7ms
# Speed: 4.6ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 150.36m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 252.83m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 312.16m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 11.0ms
# Speed: 9.1ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 223.37m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 1 motorcycle, 13.7ms
# Speed: 5.5ms preprocess, 13.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 142.37m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 14.4ms
# Speed: 3.9ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 446.73m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 11.0ms
# Speed: 4.3ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 172 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 11.0ms
# Speed: 3.6ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 11.0ms
# Speed: 3.9ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 279.21m/s² → 100으로 제한
#
# 0: 384x640 5 cars, 2 motorcycles, 11.9ms
# Speed: 4.6ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 111.68m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 12.9ms
# Speed: 3.5ms preprocess, 12.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 11.4ms
# Speed: 3.5ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 139.60m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 15.3ms
# Speed: 6.1ms preprocess, 15.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 100.67m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 782.28m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 11.1ms
# Speed: 4.1ms preprocess, 11.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 172 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 11.1ms
# Speed: 5.4ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 172 - Acceleration 너무 큼: 197.43m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 11.3ms
# Speed: 4.2ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 172 - Acceleration 너무 큼: 124.87m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 15.8ms
# Speed: 4.1ms preprocess, 15.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 11.0ms
# Speed: 5.8ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
#
# 0: 384x640 4 cars, 2 motorcycles, 11.8ms
# Speed: 8.4ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 motorcycles, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 11.8ms
# Speed: 4.3ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 11.2ms
# Speed: 4.5ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 motorcycles, 11.2ms
# Speed: 3.7ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 11.5ms
# Speed: 4.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 142.37m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 11.3ms
# Speed: 7.2ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 142.37m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 14.9ms
# Speed: 3.7ms preprocess, 14.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 5.4ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 111.68m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 11.6ms
# Speed: 3.6ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 171 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 11.5ms
# Speed: 4.4ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 12.3ms
# Speed: 4.1ms preprocess, 12.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 14.0ms
# Speed: 8.1ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 motorcycles, 11.1ms
# Speed: 9.2ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 motorcycles, 11.8ms
# Speed: 4.4ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 motorcycles, 12.9ms
# Speed: 6.2ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 11.2ms
# Speed: 4.3ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 11.6ms
# Speed: 5.0ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 motorcycles, 11.0ms
# Speed: 3.6ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 motorcycles, 11.0ms
# Speed: 3.7ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 motorcycles, 11.0ms
# Speed: 3.8ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 motorcycles, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 1145.09m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 12.5ms
# Speed: 3.9ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 motorcycle, 11.5ms
# Speed: 4.4ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 motorcycle, 11.4ms
# Speed: 6.0ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 166 - Acceleration 너무 큼: 115.12m/s² → 100으로 제한
# [DEBUG] Object 177 - Acceleration 너무 큼: 446.73m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 14.7ms
# Speed: 3.2ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 177 - Acceleration 너무 큼: 391.89m/s² → 100으로 제한
# Log data saved to: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Log data/1930-2000_log3.csv
# Interval data saved to: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Interval data/1930-2000_interval3.csv

# %%
###### Extracting Frames by video ######


import cv2
import os

def extract_frames(video_path, output_dir, frame_interval=1):
    """
    특정 경로의 비디오 파일에서 프레임을 추출하여 지정된 디렉토리에 저장하는 함수.

    :param video_path: 비디오 파일 경로 (예: "input/video.mp4")
    :param output_dir: 프레임이 저장될 디렉토리 경로 (예: "output/frames")
    :param frame_interval: 프레임을 저장할 간격 (1이면 모든 프레임 저장, 2이면 2프레임마다 저장)
    """
    # 출력 디렉토리 생성 (없으면 자동 생성)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # 비디오 캡처 객체 생성
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Error: Cannot open video file {video_path}")
        return

    frame_count = 0
    saved_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # 더 이상 프레임이 없으면 종료

        # 프레임 간격에 따라 저장 (예: 1프레임씩, 2프레임씩 저장 가능)
        if frame_count % frame_interval == 0:
            frame_filename = os.path.join(output_dir, f"frame_{saved_count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            saved_count += 1
            print(f"Saved: {frame_filename}")

        frame_count += 1

    cap.release()
    print(f"\n✅ Total {saved_count} frames saved in {output_dir}")

# 사용 예시
video_path = "/content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Log video/11.15 1930-2000_processed_video.avi"  # 입력 비디오 파일 경로
output_dir = "/content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000"  # 저장할 디렉토리
frame_interval = 1  # 모든 프레임 저장 (2이면 2프레임마다 저장)

extract_frames(video_path, output_dir, frame_interval)
# Out:
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0000.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0001.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0002.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0003.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0004.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0005.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0006.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0007.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0008.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0009.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0010.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0011.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0012.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0013.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0014.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0015.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0016.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0017.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0018.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0019.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0020.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0021.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0022.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0023.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0024.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0025.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0026.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0027.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0028.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0029.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0030.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0031.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0032.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0033.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0034.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0035.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0036.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0037.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0038.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0039.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0040.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0041.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0042.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0043.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0044.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0045.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0046.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0047.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0048.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0049.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0050.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0051.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0052.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0053.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0054.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0055.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0056.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0057.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0058.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0059.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0060.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0061.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0062.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0063.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0064.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0065.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0066.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0067.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0068.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0069.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0070.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0071.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0072.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0073.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0074.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0075.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0076.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0077.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0078.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0079.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0080.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0081.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0082.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0083.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0084.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0085.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0086.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0087.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0088.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0089.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0090.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0091.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0092.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0093.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0094.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0095.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0096.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0097.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0098.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0099.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0100.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0101.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0102.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0103.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0104.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0105.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0106.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0107.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0108.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0109.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0110.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0111.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0112.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0113.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0114.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0115.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0116.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0117.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0118.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0119.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0120.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0121.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0122.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0123.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0124.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0125.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0126.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0127.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0128.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0129.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0130.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0131.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0132.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0133.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0134.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0135.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0136.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0137.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0138.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0139.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0140.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0141.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0142.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0143.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0144.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0145.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0146.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0147.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0148.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0149.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0150.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0151.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0152.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0153.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0154.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0155.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0156.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0157.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0158.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0159.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0160.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0161.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0162.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0163.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0164.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0165.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0166.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0167.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0168.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0169.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0170.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0171.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0172.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0173.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0174.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0175.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0176.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0177.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0178.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0179.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0180.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0181.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0182.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0183.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0184.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0185.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0186.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0187.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0188.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0189.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0190.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0191.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0192.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0193.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0194.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0195.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0196.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0197.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0198.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0199.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0200.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0201.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0202.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0203.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0204.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0205.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0206.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0207.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0208.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0209.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0210.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0211.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0212.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0213.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0214.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0215.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0216.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0217.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0218.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0219.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0220.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0221.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0222.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0223.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0224.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0225.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0226.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0227.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0228.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0229.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0230.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0231.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0232.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0233.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0234.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0235.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0236.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0237.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0238.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0239.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0240.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0241.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0242.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0243.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0244.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0245.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0246.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0247.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0248.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0249.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0250.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0251.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0252.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0253.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0254.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0255.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0256.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0257.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0258.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0259.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0260.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0261.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0262.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0263.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0264.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0265.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0266.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0267.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0268.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0269.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0270.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0271.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0272.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0273.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0274.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0275.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0276.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0277.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0278.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0279.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0280.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0281.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0282.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0283.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0284.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0285.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0286.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0287.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0288.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0289.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0290.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0291.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0292.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0293.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0294.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0295.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0296.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0297.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0298.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0299.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0300.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0301.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0302.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0303.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0304.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0305.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0306.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0307.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0308.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0309.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0310.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0311.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0312.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0313.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0314.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0315.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0316.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0317.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0318.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0319.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0320.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0321.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0322.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0323.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0324.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0325.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0326.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0327.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0328.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0329.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0330.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0331.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0332.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0333.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0334.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0335.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0336.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0337.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0338.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0339.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0340.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0341.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0342.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0343.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0344.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0345.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0346.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0347.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0348.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0349.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0350.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0351.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0352.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0353.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0354.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0355.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0356.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0357.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0358.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0359.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0360.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0361.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0362.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0363.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0364.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0365.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0366.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0367.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0368.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0369.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0370.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0371.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0372.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0373.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0374.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0375.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0376.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0377.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0378.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0379.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0380.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0381.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0382.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0383.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0384.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0385.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0386.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0387.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0388.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0389.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0390.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0391.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0392.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0393.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0394.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0395.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0396.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0397.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0398.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0399.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0400.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0401.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0402.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0403.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0404.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0405.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0406.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0407.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0408.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0409.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0410.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0411.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0412.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0413.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0414.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0415.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0416.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0417.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0418.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0419.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0420.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0421.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0422.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0423.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0424.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0425.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0426.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0427.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0428.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0429.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0430.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0431.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0432.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0433.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0434.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0435.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0436.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0437.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0438.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0439.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0440.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0441.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0442.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0443.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0444.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0445.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0446.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0447.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0448.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0449.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0450.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0451.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0452.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0453.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0454.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0455.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0456.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0457.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0458.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0459.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0460.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0461.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0462.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0463.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0464.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0465.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0466.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0467.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0468.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0469.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0470.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0471.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0472.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0473.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_0474.jpg
# ...
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3564.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3565.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3566.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3567.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3568.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3569.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3570.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3571.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3572.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3573.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3574.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3575.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3576.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3577.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3578.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3579.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3580.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3581.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3582.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3583.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3584.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3585.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3586.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3587.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3588.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3589.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3590.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3591.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3592.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3593.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3594.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3595.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3596.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3597.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3598.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3599.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3600.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3601.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3602.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3603.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3604.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3605.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3606.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3607.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3608.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3609.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3610.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3611.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3612.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3613.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3614.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3615.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3616.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3617.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3618.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3619.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3620.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3621.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3622.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3623.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3624.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3625.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3626.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3627.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3628.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3629.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3630.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3631.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3632.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3633.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3634.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3635.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3636.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3637.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3638.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3639.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3640.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3641.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3642.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3643.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3644.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3645.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3646.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3647.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3648.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3649.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3650.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3651.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3652.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3653.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3654.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3655.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3656.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3657.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3658.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3659.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3660.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3661.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3662.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3663.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3664.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3665.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3666.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3667.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3668.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3669.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3670.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3671.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3672.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3673.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3674.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3675.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3676.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3677.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3678.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3679.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3680.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3681.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3682.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3683.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3684.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3685.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3686.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3687.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3688.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3689.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3690.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3691.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3692.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3693.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3694.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3695.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3696.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3697.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3698.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3699.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3700.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3701.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3702.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3703.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3704.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3705.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3706.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3707.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3708.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3709.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3710.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3711.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3712.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3713.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3714.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3715.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3716.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3717.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3718.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3719.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000/frame_3720.jpg
#
# ✅ Total 3721 frames saved in /content/drive/MyDrive/Capstone/Results/11.15 1800-2000/Frames/11.15 1930-2000
